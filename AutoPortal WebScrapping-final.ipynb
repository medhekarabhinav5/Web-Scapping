# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
import requests

# %%
CHROMEDRIVER_PATH = "/Users/Abhinav/Desktop/chromedriver" # Chrome Driver Path
CHROME_PATH = ""
WINDOW_SIZE = "1280,800" # Screen Size

# %%
chrome_options = Options()
chrome_options.add_argument("--window-size=%s" % WINDOW_SIZE)
chrome_options.add_argument("--headless")
chrome_options.binary_location = CHROME_PATH

# %%
CHROME_PATH
# Out:
# ''

# %%
prefs = {'profile.managed_default_content_settings.images' : 2}
chrome_options.add_experimental_option("prefs", prefs)

# %%
#url = "https://autoportal.com/newcars/car-finder/page/1/price/1/"

# %%
chrome_options

# %%
driver = webdriver.Chrome(
executable_path = CHROMEDRIVER_PATH,
    chrome_options = chrome_options
) # Initiate browser
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: use options instead of chrome_options
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#PHANTOMDRIVER_PATH = "/Users/Abhinav/Desktop/phantomjs-2.1.1-macosx/bin/phantomjs"
#driver = webdriver.PhantomJS(PHANTOMDRIVER_PATH, service_args=["--load-images=no"])
#driver.set_window_size(1280, 800)

# %%
unused_links = []
used_links = []

# %%
def check_exists_by_xpath(xpath): # Checking whether xpath is available
    
    try:

        driver.find_element_by_xpath(xpath)

    except:
        return False
    return True

# %% [markdown]
# //*[@id="content"]/div[2]/div[6]/div[2]/div[4]/div[1]/div[1]/div/div[2]/div[1]/div[1]/p/a

# %%
status=True # Status of 
count = 1

# %%
#getting latest details from site
while status:
    url = "https://autoportal.com/newcars/car-finder/page/" + str(count) + "/price/1/"
    request = requests.get(url) # checking whether url exists
    if request.status_code == 200: # if  status of url is 200 then it will proceed.
        driver.get(url)
        false_link_count = 0
        for i in range(1,30): # each page approx have 30 links. Some are false and of no use.
            if false_link_count < 20: # segragating false from true
                status = True
                xpath = '//*[@id="content"]/div[2]/div[6]/div[2]/div[4]/div[' + str(i) + ']/div[1]/div/div[2]/div[1]/div[1]/p/a'
                response = check_exists_by_xpath(xpath)
                if response == True:
                    link_element = driver.find_element_by_xpath(xpath)
                    link = link_element.get_attribute('href') + 'specifications/'
                    print(link)
                    unused_links.append(link) # Saving links
                else:
                    false_link_count = false_link_count + 1
            else:
                status = False
        count = count + 1
    else:
        status = False
# Out:
# https://autoportal.com/newcars/tata/nano/specifications/
# https://autoportal.com/newcars/bajaj/re60/specifications/
# https://autoportal.com/newcars/datsun/redi-go/specifications/
# https://autoportal.com/newcars/marutisuzuki/omni/specifications/
# https://autoportal.com/newcars/renault/kwid/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-800/specifications/
# https://autoportal.com/newcars/marutisuzuki/eeco/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-800-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-k10/specifications/
# https://autoportal.com/newcars/marutisuzuki/s-presso/specifications/
# https://autoportal.com/newcars/datsun/go/specifications/
# https://autoportal.com/newcars/datsun/go-plus/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio/specifications/
# https://autoportal.com/newcars/hyundai/santro/specifications/
# https://autoportal.com/newcars/marutisuzuki/wagon-r/specifications/
# https://autoportal.com/newcars/tata/tiago/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10-prime/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio-x/specifications/
# https://autoportal.com/newcars/fiat/punto-evo-pure/specifications/
# https://autoportal.com/newcars/marutisuzuki/ignis/specifications/
# https://autoportal.com/newcars/mahindra/kuv100/specifications/
# https://autoportal.com/newcars/renault/triber/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10-nios/specifications/
# https://autoportal.com/newcars/premier/rio/specifications/
# https://autoportal.com/newcars/marutisuzuki/swift/specifications/
# https://autoportal.com/newcars/toyota/etios-liva/specifications/
# https://autoportal.com/newcars/ford/figo/specifications/
# https://autoportal.com/newcars/nissan/micra-active/specifications/
# https://autoportal.com/newcars/tata/altroz/specifications/
# https://autoportal.com/newcars/tata/bolt/specifications/
# https://autoportal.com/newcars/fiat/punto-evo/specifications/
# https://autoportal.com/newcars/hyundai/xcent-prime/specifications/
# https://autoportal.com/newcars/icml/extreme/specifications/
# https://autoportal.com/newcars/marutisuzuki/dzire-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/baleno/specifications/
# https://autoportal.com/newcars/hyundai/elite-i20/specifications/
# https://autoportal.com/newcars/tata/tigor/specifications/
# https://autoportal.com/newcars/hyundai/aura/specifications/
# https://autoportal.com/newcars/hyundai/xcent/specifications/
# https://autoportal.com/newcars/volkswagen/polo/specifications/
# https://autoportal.com/newcars/tata/zest/specifications/
# https://autoportal.com/newcars/marutisuzuki/swift-dzire/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10/specifications/
# https://autoportal.com/newcars/ford/freestyle/specifications/
# https://autoportal.com/newcars/honda/amaze/specifications/
# https://autoportal.com/newcars/volkswagen/ameo/specifications/
# https://autoportal.com/newcars/tata/tiago-nrg/specifications/
# https://autoportal.com/newcars/ford/aspire/specifications/
# https://autoportal.com/newcars/marutisuzuki/gypsy/specifications/
# https://autoportal.com/newcars/toyota/etios/specifications/
# https://autoportal.com/newcars/fiat/linea-classic/specifications/
# https://autoportal.com/newcars/toyota/etios-cross/specifications/
# https://autoportal.com/newcars/hyundai/venue/specifications/
# https://autoportal.com/newcars/mahindra/verito-vibe/specifications/
# https://autoportal.com/newcars/nissan/micra/specifications/
# https://autoportal.com/newcars/fiat/urban-cross/specifications/
# https://autoportal.com/newcars/tata/nexon/specifications/
# https://autoportal.com/newcars/toyota/glanza/specifications/
# https://autoportal.com/newcars/nissan/sunny/specifications/
# https://autoportal.com/newcars/fiat/avventura/specifications/
# https://autoportal.com/newcars/fiat/linea/specifications/
# https://autoportal.com/newcars/honda/jazz/specifications/
# https://autoportal.com/newcars/mahindra/verito/specifications/
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# https://autoportal.com/newcars/ford/ecosport/specifications/
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# https://autoportal.com/newcars/renault/duster/specifications/
# https://autoportal.com/newcars/honda/wrv/specifications/
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# https://autoportal.com/newcars/renault/lodgy/specifications/
# https://autoportal.com/newcars/toyota/yaris/specifications/
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# https://autoportal.com/newcars/skoda/rapid/specifications/
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# https://autoportal.com/newcars/renault/kaptur/specifications/
# https://autoportal.com/newcars/honda/br-v/specifications/
# https://autoportal.com/newcars/nissan/kicks/specifications/
# https://autoportal.com/newcars/mahindra/thar/specifications/
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# https://autoportal.com/newcars/force/gurkha/specifications/
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# https://autoportal.com/newcars/kia/seltos/specifications/
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# https://autoportal.com/newcars/honda/city/specifications/
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# https://autoportal.com/newcars/nissan/terrano/specifications/
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# https://autoportal.com/newcars/hyundai/creta/specifications/
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# https://autoportal.com/newcars/tata/winger/specifications/
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# https://autoportal.com/newcars/mg/hector/specifications/
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# https://autoportal.com/newcars/tata/harrier/specifications/
# https://autoportal.com/newcars/tata/hexa/specifications/
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# https://autoportal.com/newcars/skoda/octavia/specifications/
# https://autoportal.com/newcars/jeep/compass/specifications/
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# https://autoportal.com/newcars/honda/civic/specifications/
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# https://autoportal.com/newcars/mg/ezs/specifications/
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# https://autoportal.com/newcars/skoda/superb/specifications/
# https://autoportal.com/newcars/jeep/compass-trailhawk/specifications/
# https://autoportal.com/newcars/mitsubishi/outlander/specifications/
# https://autoportal.com/newcars/isuzu/mu-x/specifications/
# https://autoportal.com/newcars/volvo/v40-hatchback/specifications/
# https://autoportal.com/newcars/mahindra/alturas/specifications/
# https://autoportal.com/newcars/mercedesbenz/a-class/specifications/
# https://autoportal.com/newcars/volkswagen/tiguan/specifications/
# https://autoportal.com/newcars/toyota/fortuner/specifications/
# https://autoportal.com/newcars/honda/cr-v/specifications/
# https://autoportal.com/newcars/mitsubishi/pajero-sport/specifications/
# https://autoportal.com/newcars/skoda/superb-sportline/specifications/
# https://autoportal.com/newcars/ford/endeavour/specifications/
# https://autoportal.com/newcars/audi/a3/specifications/
# https://autoportal.com/newcars/volvo/v40-cross-country/specifications/
# https://autoportal.com/newcars/mercedesbenz/b-class/specifications/
# https://autoportal.com/newcars/mini/3-door/specifications/
# https://autoportal.com/newcars/mercedesbenz/cla-class/specifications/
# https://autoportal.com/newcars/mercedesbenz/gla-class/specifications/
# https://autoportal.com/newcars/skoda/kodiaq/specifications/
# https://autoportal.com/newcars/skoda/kodiaq-scout/specifications/
# https://autoportal.com/newcars/dc/avanti/specifications/
# https://autoportal.com/newcars/mini/countryman/specifications/
# https://autoportal.com/newcars/audi/q3/specifications/
# https://autoportal.com/newcars/bmw/x1/specifications/
# https://autoportal.com/newcars/mini/5-door/specifications/
# https://autoportal.com/newcars/toyota/camry/specifications/
# https://autoportal.com/newcars/mini/convertible/specifications/
# https://autoportal.com/newcars/volvo/s60/specifications/
# https://autoportal.com/newcars/volvo/xc40/specifications/
# https://autoportal.com/newcars/mercedesbenz/c-class/specifications/
# https://autoportal.com/newcars/mini/clubman/specifications/
# https://autoportal.com/newcars/bmw/3-series/specifications/
# https://autoportal.com/newcars/audi/a4/specifications/
# https://autoportal.com/newcars/honda/accord/specifications/
# https://autoportal.com/newcars/mini/john-cooper-works/specifications/
# https://autoportal.com/newcars/volvo/volvo-s60-cross-country/specifications/
# https://autoportal.com/newcars/jaguar/xe/specifications/
# https://autoportal.com/newcars/toyota/prius/specifications/
# https://autoportal.com/newcars/jaguar/xf/specifications/
# https://autoportal.com/newcars/audi/q5/specifications/
# https://autoportal.com/newcars/audi/a3-cabriolet/specifications/
# https://autoportal.com/newcars/mercedesbenz/glc/specifications/
# https://autoportal.com/newcars/audi/a6/specifications/
# https://autoportal.com/newcars/landrover/range-rover-evoque/specifications/
# https://autoportal.com/newcars/bmw/x3/specifications/
# https://autoportal.com/newcars/lexus/es/specifications/
# https://autoportal.com/newcars/landrover/discovery-sport/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class/specifications/
# https://autoportal.com/newcars/volvo/s90/specifications/
# https://autoportal.com/newcars/bmw/5-series/specifications/
# https://autoportal.com/newcars/volvo/xc60/specifications/
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# https://autoportal.com/newcars/bmw/x4/specifications/
# https://autoportal.com/newcars/audi/a5/specifications/
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# https://autoportal.com/newcars/bmw/6-series/specifications/
# https://autoportal.com/newcars/bmw/z4/specifications/
# https://autoportal.com/newcars/volvo/v90/specifications/
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# https://autoportal.com/newcars/audi/q7/specifications/
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# https://autoportal.com/newcars/porsche/macan/specifications/
# https://autoportal.com/newcars/audi/s5/specifications/
# https://autoportal.com/newcars/landrover/velar/specifications/
# https://autoportal.com/newcars/bmw/x5/specifications/
# https://autoportal.com/newcars/mercedesbenz/gle/specifications/
# https://autoportal.com/newcars/ford/mustang/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class-all-terrain/specifications/
# https://autoportal.com/newcars/jeep/grand-cherokee/specifications/
# https://autoportal.com/newcars/landrover/discovery/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class-cabriolet/specifications/
# https://autoportal.com/newcars/volvo/xc90/specifications/
# https://autoportal.com/newcars/bmw/m2-competition/specifications/
# https://autoportal.com/newcars/mercedesbenz/cls/specifications/
# https://autoportal.com/newcars/porsche/718/specifications/
# https://autoportal.com/newcars/landrover/range-rover-sport/specifications/
# https://autoportal.com/newcars/mercedesbenz/gl/specifications/
# https://autoportal.com/newcars/jaguar/f-type/specifications/
# https://autoportal.com/newcars/toyota/land-cruiser-prado/specifications/
# https://autoportal.com/newcars/jaguar/xj/specifications/
# https://autoportal.com/newcars/lexus/rx/specifications/
# https://autoportal.com/newcars/bmw/x7/specifications/
# https://autoportal.com/newcars/audi/rs5/specifications/
# https://autoportal.com/newcars/porsche/cayenne/specifications/
# https://autoportal.com/newcars/bmw/7-series/specifications/
# https://autoportal.com/newcars/porsche/cayenne-coupe/specifications/
# https://autoportal.com/newcars/audi/q8/specifications/
# https://autoportal.com/newcars/maserati/ghibli/specifications/
# https://autoportal.com/newcars/mercedesbenz/s-class/specifications/
# https://autoportal.com/newcars/bmw/m4/specifications/
# https://autoportal.com/newcars/maserati/levante/specifications/
# https://autoportal.com/newcars/toyota/land-cruiser/specifications/
# https://autoportal.com/newcars/mercedesbenz/g-class/specifications/
# https://autoportal.com/newcars/bmw/m5/specifications/
# https://autoportal.com/newcars/audi/a8-l/specifications/
# https://autoportal.com/newcars/audi/rs7/specifications/
# https://autoportal.com/newcars/maserati/granturismo/specifications/
# https://autoportal.com/newcars/porsche/911/specifications/
# https://autoportal.com/newcars/maserati/quattroporte/specifications/
# https://autoportal.com/newcars/landrover/range-rover/specifications/
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# https://autoportal.com/newcars/lexus/lc500h/specifications/
# https://autoportal.com/newcars/maserati/grancabrio/specifications/
# https://autoportal.com/newcars/mercedesbenz/maybach/specifications/
# https://autoportal.com/newcars/nissan/gtr/specifications/
# https://autoportal.com/newcars/porsche/panamera/specifications/
# https://autoportal.com/newcars/mercedesbenz/amg-gt/specifications/
# https://autoportal.com/newcars/lexus/lx/specifications/
# https://autoportal.com/newcars/lexus/lx-570/specifications/
# https://autoportal.com/newcars/mercedesbenz/s-class-cabriolet/specifications/
# https://autoportal.com/newcars/mercedesbenz/amg-gt-4-door-coupe/specifications/
# https://autoportal.com/newcars/audi/r8/specifications/
# https://autoportal.com/newcars/astonmartin/vantage/specifications/
# https://autoportal.com/newcars/lamborghini/urus/specifications/
# https://autoportal.com/newcars/lamborghini/huracan/specifications/
# https://autoportal.com/newcars/bentley/continental-gt/specifications/
# https://autoportal.com/newcars/bentley/continental-flying-spur/specifications/
# https://autoportal.com/newcars/ferrari/portofino/specifications/
# https://autoportal.com/newcars/ferrari/488-gtb/specifications/
# https://autoportal.com/newcars/bentley/bentayga/specifications/
# https://autoportal.com/newcars/astonmartin/rapide/specifications/
# https://autoportal.com/newcars/astonmartin/db-11/specifications/
# https://autoportal.com/newcars/ferrari/gtc4-lusso/specifications/
# https://autoportal.com/newcars/ferrari/458-italia/specifications/
# https://autoportal.com/newcars/ferrari/458-spider/specifications/
# https://autoportal.com/newcars/rollsroyce/ghost-series-ii/specifications/
# https://autoportal.com/newcars/lamborghini/aventador/specifications/
# https://autoportal.com/newcars/rollsroyce/wraith/specifications/
# https://autoportal.com/newcars/ferrari/812/specifications/
# https://autoportal.com/newcars/bentley/mulsanne/specifications/
# https://autoportal.com/newcars/rollsroyce/dawn/specifications/
# https://autoportal.com/newcars/rollsroyce/cullinan/specifications/
# https://autoportal.com/newcars/rollsroyce/phantom/specifications/
# https://autoportal.com/newcars/rollsroyce/phantom-coupe/specifications/
# https://autoportal.com/newcars/rollsroyce/drophead-coupe/specifications/
# https://autoportal.com/newcars/bugatti/chiron/specifications/

# %%
driver.quit()

# %%
import time
import pprint
import re
from selenium.webdriver.support.select import Select
#time.sleep(20)
counter = 0
carInfoFull = pd.DataFrame()

# %%
col_list = ['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration', 'Emission_Norm', 'Engine_Location', 'Fuel_System', 'Fuel_Tank_Capacity', 'Fuel_Type', 'Height', 'Length', 'Width', 'Body_Type', 'Doors', 'City_Mileage', 'Highway_Mileage', 'ARAI_Certified_Mileage', 'ARAI_Certified_Mileage_for_CNG', 'Kerb_Weight', 'Gears', 'Ground_Clearance', 'Front_Brakes', 'Rear_Brakes', 'Front_Suspension', 'Rear_Suspension', 'Front_Track', 'Rear_Track', 'Front_Tyre_&_Rim', 'Rear_Tyre_&_Rim', 'Power_Steering', 'Power_Windows', 'Power_Seats', 'Keyless_Entry', 'Power', 'Torque', 'Odometer', 'Speedometer', 'Tachometer', 'Tripmeter', 'Seating_Capacity', 'Seats_Material', 'Type', 'Wheelbase', 'Wheels_Size', 'Start_/_Stop_Button','12v_Power_Outlet' ,'Audiosystem','Aux-in_Compatibility' ,'Average_Fuel_Consumption' ,'Basic_Warranty' ,'Bluetooth' ,'Boot-lid_Opener' ,'Boot_Space' ,'CD_/_MP3_/_DVD_Player' ,'Central_Locking' ,'Child_Safety_Locks' ,'Clock' ,'Cup_Holders' ,'Distance_to_Empty' ,'Door_Pockets' ,'Engine_Malfunction_Light' ,'Extended_Warranty' ,'FM_Radio' ,'Fuel-lid_Opener' ,'Fuel_Gauge' ,'Handbrake' ,'Instrument_Console' ,'Low_Fuel_Warning' ,'Minimum_Turning_Radius' ,'Multifunction_Display' ,'Sun_Visor' ,'Third_Row_AC_Vents' ,'Ventilation_System' ,'Auto-Dimming_Rear-View_Mirror' ,'Hill_Assist' ,'Gear_Indicator' ,'3_Point_Seat-Belt_in_Middle_Rear_Seat' ,'Ambient_Lightning' ,'Cargo/Boot_Lights' ,'Drive_Modes' ,'Engine_Immobilizer' ,'High_Speed_Alert_System' ,'Lane_Watch_Camera/_Side_Mirror_Camera' ,'Passenger_Side_Seat-Belt_Reminder' ,'Seat_Back_Pockets' ,'Voice_Recognition' ,'Walk_Away_Auto_Car_Lock' ,'ABS_(Anti-lock_Braking_System)' ,'Headlight_Reminder' ,'Adjustable_Headrests' ,'Gross_Vehicle_Weight' ,'Airbags' ,'Door_Ajar_Warning' ,'EBD_(Electronic_Brake-force_Distribution)' ,'Fasten_Seat_Belt_Warning' ,'Gear_Shift_Reminder' ,'Number_of_Airbags' ,'Compression_Ratio' ,'Adjustable_Steering_Column' ,'Other_Specs' ,'Other_specs' ,'Parking_Assistance' ,'Key_Off_Reminder' ,'USB_Compatibility' ,'Android_Auto' ,'Apple_CarPlay' ,'Cigarette_Lighter' ,'Infotainment_Screen' ,'Multifunction_Steering_Wheel' ,'Average_Speed' ,'EBA_(Electronic_Brake_Assist)' ,'Seat_Height_Adjustment' ,'Navigation_System' ,'Second_Row_AC_Vents' ,'Tyre_Pressure_Monitoring_System' ,'Rear_Center_Armrest' ,'iPod_Compatibility' ,'ESP_(Electronic_Stability_Program)' ,'Cooled_Glove_Box' ,'Recommended_Tyre_Pressure' ,'Heated_Seats' ,'Turbocharger' ,'ISOFIX_(Child-Seat_Mount)' ,'Rain_Sensing_Wipers', 'Paddle_Shifters' ,'Leather_Wrapped_Steering' ,'Automatic_Headlamps' ,'Engine_Type', 'ASR_/_Traction_Control' ,'Cruise_Control' ,'USB_Ports','Heads-Up_Display','Welcome_Lights' ,'Battery' ,'Electric_Range']

# %%
for unused in unused_links:
    print(unused)
# Out:
# https://autoportal.com/newcars/tata/nano/specifications/
# https://autoportal.com/newcars/bajaj/re60/specifications/
# https://autoportal.com/newcars/datsun/redi-go/specifications/
# https://autoportal.com/newcars/marutisuzuki/omni/specifications/
# https://autoportal.com/newcars/renault/kwid/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-800/specifications/
# https://autoportal.com/newcars/marutisuzuki/eeco/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-800-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/alto-k10/specifications/
# https://autoportal.com/newcars/marutisuzuki/s-presso/specifications/
# https://autoportal.com/newcars/datsun/go/specifications/
# https://autoportal.com/newcars/datsun/go-plus/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio/specifications/
# https://autoportal.com/newcars/hyundai/santro/specifications/
# https://autoportal.com/newcars/marutisuzuki/wagon-r/specifications/
# https://autoportal.com/newcars/tata/tiago/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10-prime/specifications/
# https://autoportal.com/newcars/marutisuzuki/celerio-x/specifications/
# https://autoportal.com/newcars/fiat/punto-evo-pure/specifications/
# https://autoportal.com/newcars/marutisuzuki/ignis/specifications/
# https://autoportal.com/newcars/mahindra/kuv100/specifications/
# https://autoportal.com/newcars/renault/triber/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10-nios/specifications/
# https://autoportal.com/newcars/premier/rio/specifications/
# https://autoportal.com/newcars/marutisuzuki/swift/specifications/
# https://autoportal.com/newcars/toyota/etios-liva/specifications/
# https://autoportal.com/newcars/ford/figo/specifications/
# https://autoportal.com/newcars/nissan/micra-active/specifications/
# https://autoportal.com/newcars/tata/altroz/specifications/
# https://autoportal.com/newcars/tata/bolt/specifications/
# https://autoportal.com/newcars/fiat/punto-evo/specifications/
# https://autoportal.com/newcars/hyundai/xcent-prime/specifications/
# https://autoportal.com/newcars/icml/extreme/specifications/
# https://autoportal.com/newcars/marutisuzuki/dzire-tour/specifications/
# https://autoportal.com/newcars/marutisuzuki/baleno/specifications/
# https://autoportal.com/newcars/hyundai/elite-i20/specifications/
# https://autoportal.com/newcars/tata/tigor/specifications/
# https://autoportal.com/newcars/hyundai/aura/specifications/
# https://autoportal.com/newcars/hyundai/xcent/specifications/
# https://autoportal.com/newcars/volkswagen/polo/specifications/
# https://autoportal.com/newcars/tata/zest/specifications/
# https://autoportal.com/newcars/marutisuzuki/swift-dzire/specifications/
# https://autoportal.com/newcars/hyundai/grand-i10/specifications/
# https://autoportal.com/newcars/ford/freestyle/specifications/
# https://autoportal.com/newcars/honda/amaze/specifications/
# https://autoportal.com/newcars/volkswagen/ameo/specifications/
# https://autoportal.com/newcars/tata/tiago-nrg/specifications/
# https://autoportal.com/newcars/ford/aspire/specifications/
# https://autoportal.com/newcars/marutisuzuki/gypsy/specifications/
# https://autoportal.com/newcars/toyota/etios/specifications/
# https://autoportal.com/newcars/fiat/linea-classic/specifications/
# https://autoportal.com/newcars/toyota/etios-cross/specifications/
# https://autoportal.com/newcars/hyundai/venue/specifications/
# https://autoportal.com/newcars/mahindra/verito-vibe/specifications/
# https://autoportal.com/newcars/nissan/micra/specifications/
# https://autoportal.com/newcars/fiat/urban-cross/specifications/
# https://autoportal.com/newcars/tata/nexon/specifications/
# https://autoportal.com/newcars/toyota/glanza/specifications/
# https://autoportal.com/newcars/nissan/sunny/specifications/
# https://autoportal.com/newcars/fiat/avventura/specifications/
# https://autoportal.com/newcars/fiat/linea/specifications/
# https://autoportal.com/newcars/honda/jazz/specifications/
# https://autoportal.com/newcars/mahindra/verito/specifications/
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# https://autoportal.com/newcars/ford/ecosport/specifications/
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# https://autoportal.com/newcars/renault/duster/specifications/
# https://autoportal.com/newcars/honda/wrv/specifications/
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# https://autoportal.com/newcars/renault/lodgy/specifications/
# https://autoportal.com/newcars/toyota/yaris/specifications/
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# https://autoportal.com/newcars/skoda/rapid/specifications/
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# https://autoportal.com/newcars/renault/kaptur/specifications/
# https://autoportal.com/newcars/honda/br-v/specifications/
# https://autoportal.com/newcars/nissan/kicks/specifications/
# https://autoportal.com/newcars/mahindra/thar/specifications/
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# https://autoportal.com/newcars/force/gurkha/specifications/
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# https://autoportal.com/newcars/kia/seltos/specifications/
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# https://autoportal.com/newcars/honda/city/specifications/
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# https://autoportal.com/newcars/nissan/terrano/specifications/
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# https://autoportal.com/newcars/hyundai/creta/specifications/
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# https://autoportal.com/newcars/tata/winger/specifications/
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# https://autoportal.com/newcars/mg/hector/specifications/
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# https://autoportal.com/newcars/tata/harrier/specifications/
# https://autoportal.com/newcars/tata/hexa/specifications/
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# https://autoportal.com/newcars/skoda/octavia/specifications/
# https://autoportal.com/newcars/jeep/compass/specifications/
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# https://autoportal.com/newcars/honda/civic/specifications/
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# https://autoportal.com/newcars/mg/ezs/specifications/
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# https://autoportal.com/newcars/skoda/superb/specifications/
# https://autoportal.com/newcars/jeep/compass-trailhawk/specifications/
# https://autoportal.com/newcars/mitsubishi/outlander/specifications/
# https://autoportal.com/newcars/isuzu/mu-x/specifications/
# https://autoportal.com/newcars/volvo/v40-hatchback/specifications/
# https://autoportal.com/newcars/mahindra/alturas/specifications/
# https://autoportal.com/newcars/mercedesbenz/a-class/specifications/
# https://autoportal.com/newcars/volkswagen/tiguan/specifications/
# https://autoportal.com/newcars/toyota/fortuner/specifications/
# https://autoportal.com/newcars/honda/cr-v/specifications/
# https://autoportal.com/newcars/mitsubishi/pajero-sport/specifications/
# https://autoportal.com/newcars/skoda/superb-sportline/specifications/
# https://autoportal.com/newcars/ford/endeavour/specifications/
# https://autoportal.com/newcars/audi/a3/specifications/
# https://autoportal.com/newcars/volvo/v40-cross-country/specifications/
# https://autoportal.com/newcars/mercedesbenz/b-class/specifications/
# https://autoportal.com/newcars/mini/3-door/specifications/
# https://autoportal.com/newcars/mercedesbenz/cla-class/specifications/
# https://autoportal.com/newcars/mercedesbenz/gla-class/specifications/
# https://autoportal.com/newcars/skoda/kodiaq/specifications/
# https://autoportal.com/newcars/skoda/kodiaq-scout/specifications/
# https://autoportal.com/newcars/dc/avanti/specifications/
# https://autoportal.com/newcars/mini/countryman/specifications/
# https://autoportal.com/newcars/audi/q3/specifications/
# https://autoportal.com/newcars/bmw/x1/specifications/
# https://autoportal.com/newcars/mini/5-door/specifications/
# https://autoportal.com/newcars/toyota/camry/specifications/
# https://autoportal.com/newcars/mini/convertible/specifications/
# https://autoportal.com/newcars/volvo/s60/specifications/
# https://autoportal.com/newcars/volvo/xc40/specifications/
# https://autoportal.com/newcars/mercedesbenz/c-class/specifications/
# https://autoportal.com/newcars/mini/clubman/specifications/
# https://autoportal.com/newcars/bmw/3-series/specifications/
# https://autoportal.com/newcars/audi/a4/specifications/
# https://autoportal.com/newcars/honda/accord/specifications/
# https://autoportal.com/newcars/mini/john-cooper-works/specifications/
# https://autoportal.com/newcars/volvo/volvo-s60-cross-country/specifications/
# https://autoportal.com/newcars/jaguar/xe/specifications/
# https://autoportal.com/newcars/toyota/prius/specifications/
# https://autoportal.com/newcars/jaguar/xf/specifications/
# https://autoportal.com/newcars/audi/q5/specifications/
# https://autoportal.com/newcars/audi/a3-cabriolet/specifications/
# https://autoportal.com/newcars/mercedesbenz/glc/specifications/
# https://autoportal.com/newcars/audi/a6/specifications/
# https://autoportal.com/newcars/landrover/range-rover-evoque/specifications/
# https://autoportal.com/newcars/bmw/x3/specifications/
# https://autoportal.com/newcars/lexus/es/specifications/
# https://autoportal.com/newcars/landrover/discovery-sport/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class/specifications/
# https://autoportal.com/newcars/volvo/s90/specifications/
# https://autoportal.com/newcars/bmw/5-series/specifications/
# https://autoportal.com/newcars/volvo/xc60/specifications/
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# https://autoportal.com/newcars/bmw/x4/specifications/
# https://autoportal.com/newcars/audi/a5/specifications/
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# https://autoportal.com/newcars/bmw/6-series/specifications/
# https://autoportal.com/newcars/bmw/z4/specifications/
# https://autoportal.com/newcars/volvo/v90/specifications/
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# https://autoportal.com/newcars/audi/q7/specifications/
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# https://autoportal.com/newcars/porsche/macan/specifications/
# https://autoportal.com/newcars/audi/s5/specifications/
# https://autoportal.com/newcars/landrover/velar/specifications/
# https://autoportal.com/newcars/bmw/x5/specifications/
# https://autoportal.com/newcars/mercedesbenz/gle/specifications/
# https://autoportal.com/newcars/ford/mustang/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class-all-terrain/specifications/
# https://autoportal.com/newcars/jeep/grand-cherokee/specifications/
# https://autoportal.com/newcars/landrover/discovery/specifications/
# https://autoportal.com/newcars/mercedesbenz/e-class-cabriolet/specifications/
# https://autoportal.com/newcars/volvo/xc90/specifications/
# https://autoportal.com/newcars/bmw/m2-competition/specifications/
# https://autoportal.com/newcars/mercedesbenz/cls/specifications/
# https://autoportal.com/newcars/porsche/718/specifications/
# https://autoportal.com/newcars/landrover/range-rover-sport/specifications/
# https://autoportal.com/newcars/mercedesbenz/gl/specifications/
# https://autoportal.com/newcars/jaguar/f-type/specifications/
# https://autoportal.com/newcars/toyota/land-cruiser-prado/specifications/
# https://autoportal.com/newcars/jaguar/xj/specifications/
# https://autoportal.com/newcars/lexus/rx/specifications/
# https://autoportal.com/newcars/bmw/x7/specifications/
# https://autoportal.com/newcars/audi/rs5/specifications/
# https://autoportal.com/newcars/porsche/cayenne/specifications/
# https://autoportal.com/newcars/bmw/7-series/specifications/
# https://autoportal.com/newcars/porsche/cayenne-coupe/specifications/
# https://autoportal.com/newcars/audi/q8/specifications/
# https://autoportal.com/newcars/maserati/ghibli/specifications/
# https://autoportal.com/newcars/mercedesbenz/s-class/specifications/
# https://autoportal.com/newcars/bmw/m4/specifications/
# https://autoportal.com/newcars/maserati/levante/specifications/
# https://autoportal.com/newcars/toyota/land-cruiser/specifications/
# https://autoportal.com/newcars/mercedesbenz/g-class/specifications/
# https://autoportal.com/newcars/bmw/m5/specifications/
# https://autoportal.com/newcars/audi/a8-l/specifications/
# https://autoportal.com/newcars/audi/rs7/specifications/
# https://autoportal.com/newcars/maserati/granturismo/specifications/
# https://autoportal.com/newcars/porsche/911/specifications/
# https://autoportal.com/newcars/maserati/quattroporte/specifications/
# https://autoportal.com/newcars/landrover/range-rover/specifications/
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# https://autoportal.com/newcars/lexus/lc500h/specifications/
# https://autoportal.com/newcars/maserati/grancabrio/specifications/
# https://autoportal.com/newcars/mercedesbenz/maybach/specifications/
# https://autoportal.com/newcars/nissan/gtr/specifications/
# https://autoportal.com/newcars/porsche/panamera/specifications/
# https://autoportal.com/newcars/mercedesbenz/amg-gt/specifications/
# https://autoportal.com/newcars/lexus/lx/specifications/
# https://autoportal.com/newcars/lexus/lx-570/specifications/
# https://autoportal.com/newcars/mercedesbenz/s-class-cabriolet/specifications/
# https://autoportal.com/newcars/mercedesbenz/amg-gt-4-door-coupe/specifications/
# https://autoportal.com/newcars/audi/r8/specifications/
# https://autoportal.com/newcars/astonmartin/vantage/specifications/
# https://autoportal.com/newcars/lamborghini/urus/specifications/
# https://autoportal.com/newcars/lamborghini/huracan/specifications/
# https://autoportal.com/newcars/bentley/continental-gt/specifications/
# https://autoportal.com/newcars/bentley/continental-flying-spur/specifications/
# https://autoportal.com/newcars/ferrari/portofino/specifications/
# https://autoportal.com/newcars/ferrari/488-gtb/specifications/
# https://autoportal.com/newcars/bentley/bentayga/specifications/
# https://autoportal.com/newcars/astonmartin/rapide/specifications/
# https://autoportal.com/newcars/astonmartin/db-11/specifications/
# https://autoportal.com/newcars/ferrari/gtc4-lusso/specifications/
# https://autoportal.com/newcars/ferrari/458-italia/specifications/
# https://autoportal.com/newcars/ferrari/458-spider/specifications/
# https://autoportal.com/newcars/rollsroyce/ghost-series-ii/specifications/
# https://autoportal.com/newcars/lamborghini/aventador/specifications/
# https://autoportal.com/newcars/rollsroyce/wraith/specifications/
# https://autoportal.com/newcars/ferrari/812/specifications/
# https://autoportal.com/newcars/bentley/mulsanne/specifications/
# https://autoportal.com/newcars/rollsroyce/dawn/specifications/
# https://autoportal.com/newcars/rollsroyce/cullinan/specifications/
# https://autoportal.com/newcars/rollsroyce/phantom/specifications/
# https://autoportal.com/newcars/rollsroyce/phantom-coupe/specifications/
# https://autoportal.com/newcars/rollsroyce/drophead-coupe/specifications/
# https://autoportal.com/newcars/bugatti/chiron/specifications/

# %%
test_links = ['https://autoportal.com/newcars/renault/kwid/specifications/','https://autoportal.com/newcars/datsun/go/specifications/']
for link in test_links:
    print(link)
# Out:
# https://autoportal.com/newcars/renault/kwid/specifications/
# https://autoportal.com/newcars/datsun/go/specifications/

# %%
import random
unused_count = len(unused_links)
while unused_count != 0:
    for unused in unused_links:
        driver = webdriver.Chrome(
        executable_path = CHROMEDRIVER_PATH,
        chrome_options = chrome_options
        ) # Initiate browser
        #driver = webdriver.PhantomJS(PHANTOMDRIVER_PATH, service_args=["--load-images=no"])
        #driver.set_window_size(1280, 800)
        #print(link)
        link_process_flag = False
        attempt_count = 1
        while link_process_flag == False and attempt_count < 4:
            try:
                print(unused)
                driver.get(unused) 
                mySelect = Select(driver.find_element_by_name("variant_key")) #getting element by variant dropdown
                variants = len(mySelect.options) # getting number of variant
                variant_count = 0 # variant Count
                carInfo = pd.DataFrame()  # to store final data of cars # Empty Dataframe
                for i in range(0,variants):
                    counter = counter + 1
                    variant_count = variant_count + 1 
                    mySelect = Select(driver.find_element_by_name("variant_key"))
                    status = mySelect.select_by_index(i) # selecting Variant
                    time.sleep(15)    # wait till page changes
                    acar_info_dict = {} # to store data of each model-variant
                    ################################################################
                    make_final = '' # final value of make
                    model_final = ''  # final value of model
                    variant_final = '' # final value of variant

                    make = unused.split("/")[4].strip() # fetching make name from link 
                    make_model_xpath = '//*[@id="content"]/div/div[9]/div[1]/section/h2' # getting string from page where only make and model is mentioned- No variant mentioned
                    make_model_variant_xpath = '//*[@id="content"]/div/div[10]/p' # getting  string from page where all 3 are mentioned
                    make_model = driver.find_element_by_xpath(make_model_xpath).text.split("of ",1)[1] # Splitting Make_model String
                    make_model_variant = driver.find_element_by_xpath(make_model_variant_xpath).text.rsplit(' ', 1)[0].split("of ",1)[1] # Splitting make_model_variant string and removeing last word from it
                    model_label = 'Model' # make label
                    make_label = 'Make' # model label
                    variant_label = 'Variant' # variant label

                    for make_name in make_model.lower().split(): # for loop for make model split
                        if make_name.lower() in make.lower(): # checking whether work matched woth make string
                            make_final = make_final + "" + make_name.title() + " " # appending

                    for model_name in make_model.lower().split(): # for loop for make model split
                        if model_name.lower() not in make.lower(): # Checking whether splits are not matching woth make # not making will be in list
                            model_final = model_final + "" + model_name.title() + " " # appending

                    make_model_split = make_model.lower().split() # make model stplit variable
                    make_model_variant_split = make_model_variant.lower().split() # make model variant split variable

                    variant = [ ele for ele in make_model_variant_split ] # getting world wise split in list
                    for a in make_model_split: 
                        if a in make_model_variant_split:  # checking if matches
                            variant.remove(a) # if matches , removed from list. remaining will be variant

                    for i in variant:
                        variant_final = variant_final + "" + i.title() + " " # Appending
                    acar_info_dict[make_label] = make_final.rstrip() # adding to dictionary
                    acar_info_dict[model_label] = model_final.rstrip() # adding to dictionary
                    acar_info_dict[variant_label] = variant_final.rstrip() # adding to dictionary
                    ################################################################        
                    price_xpath = '//*[@id="content"]/div/div[10]/div/div[1]/ul/li[1]/div/div[2]/p' # price Path
                    price_label = 'Ex-Showroom_Price'# price label
                    price = driver.find_element_by_xpath(price_xpath).text # getting price text from xpath
                    acar_info_dict[price_label] = price # adding price to dictionary
                    ################################################################
                    tech_specs = True # status of lop
                    tech_specs_count = 1 # for looping
                    while tech_specs:
                        # Checking if label exists
                        label_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[1]/div[' + str(tech_specs_count) + ']/div[1]')
                        # Checking if value exists
                        value_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[1]/div[' + str(tech_specs_count) + ']/div[2]')
                        if (label_check == True) and (value_check == True): # if both true, label and value exists
                            tech_specs = True
                            element1 = (driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[1]/div[' + str(tech_specs_count) + ']/div[1]').text).replace(" ", "_")
                            element2 = driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[1]/div[' + str(tech_specs_count) + ']/div[2]').text
                            acar_info_dict[element1] = element2 # saving details in dictionary
                            tech_specs_count = tech_specs_count + 1
                        elif (label_check == True) and (value_check == False): # if value is false then it is of no use. Skipping it
                            tech_specs = True
                            tech_specs_count = tech_specs_count + 1    
                        else:
                            tech_specs = False
                    ##################################################################        
                    features_specs = True # status of lop
                    features_specs_count = 1 # for looping
                    while features_specs:
                        # Checking if label exists
                        label_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[2]/div[' + str(features_specs_count) + ']/div[1]')
                        # Checking if value exists
                        value_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[2]/div[' + str(features_specs_count) + ']/div[2]')
                        if (label_check == True) and (value_check == True): # if both true, label and value exists
                            features_specs = True
                            element1 = (driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[2]/div[' + str(features_specs_count) + ']/div[1]').text).replace(" ", "_")
                            element2 = driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[2]/div[' + str(features_specs_count) + ']/div[2]').text
                            acar_info_dict[element1] = element2 # saving details in dictionary
                            features_specs_count = features_specs_count + 1
                        elif (label_check == True) and (value_check == False): # if value is false then it is of no use. Skipping it
                            features_specs = True
                            features_specs_count = features_specs_count + 1    
                        else:
                            features_specs = False
                    #####################################################################  
                    dims_specs = True # status of lop
                    dims_specs_count = 1 # for looping
                    while dims_specs:
                        # Checking if label exists
                        label_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[3]/div[' + str(dims_specs_count) + ']/div[1]')
                        # Checking if value exists
                        value_check = check_exists_by_xpath('//*[@id="content"]/div/section[1]/div[3]/div[' + str(dims_specs_count) + ']/div[2]')
                        if (label_check == True) and (value_check == True): # if both true, label and value exists
                            dims_specs = True
                            element1 = (driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[3]/div[' + str(dims_specs_count) + ']/div[1]').text).replace(" ", "_")
                            element2 = driver.find_element_by_xpath('//*[@id="content"]/div/section[1]/div[3]/div[' + str(dims_specs_count) + ']/div[2]').text
                            acar_info_dict[element1] = element2 # saving details in dictionary
                            dims_specs_count = dims_specs_count + 1
                        elif (label_check == True) and (value_check == False): # if value is false then it is of no use. Skipping it
                            dims_specs = True
                            dims_specs_count = dims_specs_count + 1    
                        else:
                            dims_specs = False
                    #print(acar_info_dict)
                    carInfo = carInfo.append(acar_info_dict, ignore_index=True)
                    carInfoFull = carInfoFull.append(acar_info_dict, ignore_index=True)
                print(counter)
                carInfo.reindex(columns=col_list).to_csv(r'/Users/Abhinav/Movies/DataSets/cars_ds_' + make_final.strip().replace(" ", "_") + '_' + model_final.strip().replace(" ", "_") + '.csv',header=True)
                link_process_flag = True
                used_links.append(unused)
                unused_links.remove(unused)
                unused_count = len(unused_links)
                print("Unused Links count is " + str(unused_count))
                driver.quit()
            except:
                unused_count = len(unused_links)
                print("Unused Links count is " + str(unused_count))
                attempt_count = attempt_count + 1
                print("Attempts for " + make_final.strip() + " " + model_final.strip() + "is" + str(attempt_count))
                link_process_flag = False
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys
# https://autoportal.com/newcars/tata/nano/specifications/
# 6
# Unused Links count is 262
# https://autoportal.com/newcars/datsun/redi-go/specifications/
# 12
# Unused Links count is 261
# https://autoportal.com/newcars/renault/kwid/specifications/
# 24
# Unused Links count is 260
# https://autoportal.com/newcars/marutisuzuki/eeco/specifications/
# 29
# Unused Links count is 259
# https://autoportal.com/newcars/marutisuzuki/alto-k10/specifications/
# 35
# Unused Links count is 258
# https://autoportal.com/newcars/datsun/go/specifications/
# 44
# Unused Links count is 257
# https://autoportal.com/newcars/marutisuzuki/celerio-tour/specifications/
# 46
# Unused Links count is 256
# https://autoportal.com/newcars/hyundai/santro/specifications/
# 54
# Unused Links count is 255
# https://autoportal.com/newcars/tata/tiago/specifications/
# 62
# Unused Links count is 254
# https://autoportal.com/newcars/marutisuzuki/celerio-x/specifications/
# 70
# Unused Links count is 253
# https://autoportal.com/newcars/marutisuzuki/ignis/specifications/
# 77
# Unused Links count is 252
# https://autoportal.com/newcars/renault/triber/specifications/
# 81
# Unused Links count is 251
# https://autoportal.com/newcars/premier/rio/specifications/
# 87
# Unused Links count is 250
# https://autoportal.com/newcars/toyota/etios-liva/specifications/
# 101
# Unused Links count is 249
# https://autoportal.com/newcars/nissan/micra-active/specifications/
# 104
# Unused Links count is 248
# https://autoportal.com/newcars/tata/bolt/specifications/
# 112
# Unused Links count is 247
# https://autoportal.com/newcars/hyundai/xcent-prime/specifications/
# 118
# Unused Links count is 246
# https://autoportal.com/newcars/marutisuzuki/dzire-tour/specifications/
# 121
# Unused Links count is 245
# https://autoportal.com/newcars/hyundai/elite-i20/specifications/
# 133
# Unused Links count is 244
# https://autoportal.com/newcars/hyundai/aura/specifications/
# 145
# Unused Links count is 243
# https://autoportal.com/newcars/volkswagen/polo/specifications/
# 153
# Unused Links count is 242
# https://autoportal.com/newcars/marutisuzuki/swift-dzire/specifications/
# 167
# Unused Links count is 241
# https://autoportal.com/newcars/ford/freestyle/specifications/
# 175
# Unused Links count is 240
# https://autoportal.com/newcars/volkswagen/ameo/specifications/
# 183
# Unused Links count is 239
# https://autoportal.com/newcars/ford/aspire/specifications/
# 196
# Unused Links count is 238
# https://autoportal.com/newcars/toyota/etios/specifications/
# 206
# Unused Links count is 237
# https://autoportal.com/newcars/toyota/etios-cross/specifications/
# 212
# Unused Links count is 236
# https://autoportal.com/newcars/mahindra/verito-vibe/specifications/
# 215
# Unused Links count is 235
# https://autoportal.com/newcars/fiat/urban-cross/specifications/
# 219
# Unused Links count is 234
# https://autoportal.com/newcars/toyota/glanza/specifications/
# 224
# Unused Links count is 233
# https://autoportal.com/newcars/fiat/avventura/specifications/
# 227
# Unused Links count is 232
# https://autoportal.com/newcars/honda/jazz/specifications/
# 235
# Unused Links count is 231
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/ford/ecosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/ford/ecosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/ford/ecosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/renault/duster/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/renault/duster/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/renault/duster/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/honda/wrv/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/honda/wrv/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/honda/wrv/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/renault/lodgy/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/renault/lodgy/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/renault/lodgy/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/toyota/yaris/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/toyota/yaris/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/toyota/yaris/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/skoda/rapid/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/skoda/rapid/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/skoda/rapid/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/renault/kaptur/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/renault/kaptur/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/renault/kaptur/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/honda/br-v/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/honda/br-v/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/honda/br-v/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/nissan/kicks/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/nissan/kicks/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/nissan/kicks/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/thar/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/thar/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/thar/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/force/gurkha/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/force/gurkha/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/force/gurkha/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/kia/seltos/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/kia/seltos/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/kia/seltos/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/honda/city/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/honda/city/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/honda/city/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/nissan/terrano/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/nissan/terrano/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/nissan/terrano/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/creta/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/creta/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/creta/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/winger/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/winger/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/winger/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mg/hector/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mg/hector/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mg/hector/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/harrier/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/harrier/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/harrier/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/hexa/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/hexa/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/hexa/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/skoda/octavia/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/skoda/octavia/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/skoda/octavia/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/jeep/compass/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/jeep/compass/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/jeep/compass/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/honda/civic/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/honda/civic/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/honda/civic/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/mg/ezs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/mg/ezs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/mg/ezs/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/skoda/superb/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/skoda/superb/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis3
# https://autoportal.com/newcars/skoda/superb/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis4
# https://autoportal.com/newcars/jeep/compass-trailhawk/specifications/
# Unused Links count is 231
# Attempts for Honda Jazzis2
# https://autoportal.com/newcars/jeep/compass-trailhawk/specifications/
# 237
# Unused Links count is 230
# https://autoportal.com/newcars/isuzu/mu-x/specifications/
# 239
# Unused Links count is 229
# https://autoportal.com/newcars/mahindra/alturas/specifications/
# 241
# Unused Links count is 228
# https://autoportal.com/newcars/volkswagen/tiguan/specifications/
# 243
# Unused Links count is 227
# https://autoportal.com/newcars/honda/cr-v/specifications/
# 246
# Unused Links count is 226
# https://autoportal.com/newcars/skoda/superb-sportline/specifications/
# 248
# Unused Links count is 225
# https://autoportal.com/newcars/audi/a3/specifications/
# 252
# Unused Links count is 224
# https://autoportal.com/newcars/mercedesbenz/b-class/specifications/
# 256
# Unused Links count is 223
# https://autoportal.com/newcars/mercedesbenz/cla-class/specifications/
# 259
# Unused Links count is 222
# https://autoportal.com/newcars/skoda/kodiaq/specifications/
# 262
# Unused Links count is 221
# https://autoportal.com/newcars/dc/avanti/specifications/
# 263
# Unused Links count is 220
# https://autoportal.com/newcars/audi/q3/specifications/
# 267
# Unused Links count is 219
# https://autoportal.com/newcars/mini/5-door/specifications/
# 268
# Unused Links count is 218
# https://autoportal.com/newcars/mini/convertible/specifications/
# 269
# Unused Links count is 217
# https://autoportal.com/newcars/volvo/xc40/specifications/
# 272
# Unused Links count is 216
# https://autoportal.com/newcars/mini/clubman/specifications/
# 273
# Unused Links count is 215
# https://autoportal.com/newcars/audi/a4/specifications/
# 275
# Unused Links count is 214
# https://autoportal.com/newcars/mini/john-cooper-works/specifications/
# 276
# Unused Links count is 213
# https://autoportal.com/newcars/jaguar/xe/specifications/
# 280
# Unused Links count is 212
# https://autoportal.com/newcars/jaguar/xf/specifications/
# 285
# Unused Links count is 211
# https://autoportal.com/newcars/audi/a3-cabriolet/specifications/
# 286
# Unused Links count is 210
# https://autoportal.com/newcars/audi/a6/specifications/
# 288
# Unused Links count is 209
# https://autoportal.com/newcars/bmw/x3/specifications/
# 291
# Unused Links count is 208
# https://autoportal.com/newcars/landrover/discovery-sport/specifications/
# 293
# Unused Links count is 207
# https://autoportal.com/newcars/volvo/s90/specifications/
# 294
# Unused Links count is 206
# https://autoportal.com/newcars/volvo/xc60/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/volvo/xc60/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/volvo/xc60/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/bmw/x4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/bmw/x4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/bmw/x4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/audi/a5/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/audi/a5/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/audi/a5/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/bmw/6-series/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/bmw/6-series/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/bmw/6-series/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/bmw/z4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/bmw/z4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/bmw/z4/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/volvo/v90/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/volvo/v90/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/volvo/v90/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/audi/q7/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/audi/q7/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/audi/q7/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/porsche/macan/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/porsche/macan/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/porsche/macan/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is4
# https://autoportal.com/newcars/audi/s5/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is2
# https://autoportal.com/newcars/audi/s5/specifications/
# Unused Links count is 206
# Attempts for Volvo S90is3
# https://autoportal.com/newcars/audi/s5/specifications/
# 295
# Unused Links count is 205
# https://autoportal.com/newcars/bmw/x5/specifications/
# 298
# Unused Links count is 204
# https://autoportal.com/newcars/ford/mustang/specifications/
# 299
# Unused Links count is 203
# https://autoportal.com/newcars/jeep/grand-cherokee/specifications/
# 303
# Unused Links count is 202
# https://autoportal.com/newcars/mercedesbenz/e-class-cabriolet/specifications/
# 304
# Unused Links count is 201
# https://autoportal.com/newcars/bmw/m2-competition/specifications/
# 305
# Unused Links count is 200
# https://autoportal.com/newcars/porsche/718/specifications/
# 307
# Unused Links count is 199
# https://autoportal.com/newcars/mercedesbenz/gl/specifications/
# 312
# Unused Links count is 198
# https://autoportal.com/newcars/toyota/land-cruiser-prado/specifications/
# 313
# Unused Links count is 197
# https://autoportal.com/newcars/lexus/rx/specifications/
# 314
# Unused Links count is 196
# https://autoportal.com/newcars/audi/rs5/specifications/
# 315
# Unused Links count is 195
# https://autoportal.com/newcars/bmw/7-series/specifications/
# 321
# Unused Links count is 194
# https://autoportal.com/newcars/audi/q8/specifications/
# 322
# Unused Links count is 193
# https://autoportal.com/newcars/mercedesbenz/s-class/specifications/
# 325
# Unused Links count is 192
# https://autoportal.com/newcars/maserati/levante/specifications/
# 328
# Unused Links count is 191
# https://autoportal.com/newcars/mercedesbenz/g-class/specifications/
# 330
# Unused Links count is 190
# https://autoportal.com/newcars/audi/a8-l/specifications/
# 331
# Unused Links count is 189
# https://autoportal.com/newcars/maserati/granturismo/specifications/
# 332
# Unused Links count is 188
# https://autoportal.com/newcars/maserati/quattroporte/specifications/
# 333
# Unused Links count is 187
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# Unused Links count is 187
# Attempts for Maserati Quattroporteis2
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# Unused Links count is 187
# Attempts for Maserati Quattroporteis3
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# Unused Links count is 187
# Attempts for Maserati Quattroporteis4
# https://autoportal.com/newcars/lexus/lc500h/specifications/
# Unused Links count is 187
# Attempts for Maserati Quattroporteis2
# https://autoportal.com/newcars/lexus/lc500h/specifications/
# 334
# Unused Links count is 186
# https://autoportal.com/newcars/mercedesbenz/maybach/specifications/
# 336
# Unused Links count is 185
# https://autoportal.com/newcars/porsche/panamera/specifications/
# 339
# Unused Links count is 184
# https://autoportal.com/newcars/lexus/lx/specifications/
# 340
# Unused Links count is 183
# https://autoportal.com/newcars/mercedesbenz/s-class-cabriolet/specifications/
# 341
# Unused Links count is 182
# https://autoportal.com/newcars/audi/r8/specifications/
# 342
# Unused Links count is 181
# https://autoportal.com/newcars/lamborghini/urus/specifications/
# 343
# Unused Links count is 180
# https://autoportal.com/newcars/bentley/continental-gt/specifications/
# 344
# Unused Links count is 179
# https://autoportal.com/newcars/ferrari/portofino/specifications/
# 345
# Unused Links count is 178
# https://autoportal.com/newcars/bentley/bentayga/specifications/
# 347
# Unused Links count is 177
# https://autoportal.com/newcars/astonmartin/db-11/specifications/
# 348
# Unused Links count is 176
# https://autoportal.com/newcars/ferrari/458-italia/specifications/
# 349
# Unused Links count is 175
# https://autoportal.com/newcars/rollsroyce/ghost-series-ii/specifications/
# 351
# Unused Links count is 174
# https://autoportal.com/newcars/rollsroyce/wraith/specifications/
# 352
# Unused Links count is 173
# https://autoportal.com/newcars/bentley/mulsanne/specifications/
# 353
# Unused Links count is 172
# https://autoportal.com/newcars/rollsroyce/cullinan/specifications/
# 354
# Unused Links count is 171
# https://autoportal.com/newcars/rollsroyce/phantom-coupe/specifications/
# 355
# Unused Links count is 170
# https://autoportal.com/newcars/bugatti/chiron/specifications/
# 357
# Unused Links count is 169
# https://autoportal.com/newcars/bajaj/re60/specifications/
# 359
# Unused Links count is 168
# https://autoportal.com/newcars/marutisuzuki/alto-800/specifications/
# 367
# Unused Links count is 167
# https://autoportal.com/newcars/marutisuzuki/s-presso/specifications/
# 377
# Unused Links count is 166
# https://autoportal.com/newcars/marutisuzuki/celerio/specifications/
# 388
# Unused Links count is 165
# https://autoportal.com/newcars/hyundai/grand-i10-prime/specifications/
# 394
# Unused Links count is 164
# https://autoportal.com/newcars/mahindra/kuv100/specifications/
# 416
# Unused Links count is 163
# https://autoportal.com/newcars/marutisuzuki/swift/specifications/
# 430
# Unused Links count is 162
# https://autoportal.com/newcars/tata/altroz/specifications/
# 440
# Unused Links count is 161
# https://autoportal.com/newcars/icml/extreme/specifications/
# 451
# Unused Links count is 160
# https://autoportal.com/newcars/tata/tigor/specifications/
# 457
# Unused Links count is 159
# https://autoportal.com/newcars/tata/zest/specifications/
# 468
# Unused Links count is 158
# https://autoportal.com/newcars/honda/amaze/specifications/
# 488
# Unused Links count is 157
# https://autoportal.com/newcars/marutisuzuki/gypsy/specifications/
# 490
# Unused Links count is 156
# https://autoportal.com/newcars/hyundai/venue/specifications/
# 503
# Unused Links count is 155
# https://autoportal.com/newcars/tata/nexon/specifications/
# 527
# Unused Links count is 154
# https://autoportal.com/newcars/fiat/linea/specifications/
# 532
# Unused Links count is 153
# https://autoportal.com/newcars/mahindra/bolero-power-plus/specifications/
# 538
# Unused Links count is 152
# https://autoportal.com/newcars/marutisuzuki/vitara-brezza/specifications/
# 547
# Unused Links count is 151
# https://autoportal.com/newcars/hyundai/i20-active/specifications/
# 551
# Unused Links count is 150
# https://autoportal.com/newcars/ford/ecosport/specifications/
# 563
# Unused Links count is 149
# https://autoportal.com/newcars/renault/duster/specifications/
# 572
# Unused Links count is 148
# https://autoportal.com/newcars/hyundai/new-verna/specifications/
# 585
# Unused Links count is 147
# https://autoportal.com/newcars/mahindra/xuv-300/specifications/
# 596
# Unused Links count is 146
# https://autoportal.com/newcars/renault/lodgy/specifications/
# 603
# Unused Links count is 145
# https://autoportal.com/newcars/volkswagen/vento/specifications/
# 615
# Unused Links count is 144
# https://autoportal.com/newcars/mahindra/e2o-plus/specifications/
# 617
# Unused Links count is 143
# https://autoportal.com/newcars/tata/tigor-ev/specifications/
# 620
# Unused Links count is 142
# https://autoportal.com/newcars/honda/br-v/specifications/
# 628
# Unused Links count is 141
# https://autoportal.com/newcars/mahindra/thar/specifications/
# 631
# Unused Links count is 140
# https://autoportal.com/newcars/force/gurkha/specifications/
# 637
# Unused Links count is 139
# https://autoportal.com/newcars/marutisuzuki/xl6/specifications/
# 641
# Unused Links count is 138
# https://autoportal.com/newcars/fiat/abarth-avventura/specifications/
# 642
# Unused Links count is 137
# https://autoportal.com/newcars/mahindra/tuv300-plus/specifications/
# 645
# Unused Links count is 136
# https://autoportal.com/newcars/mahindra/marazzo/specifications/
# 653
# Unused Links count is 135
# https://autoportal.com/newcars/mahindra/scorpio/specifications/
# 662
# Unused Links count is 134
# https://autoportal.com/newcars/skoda/monte-carlo/specifications/
# 666
# Unused Links count is 133
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# Unused Links count is 133
# Attempts for  is2
# https://autoportal.com/newcars/mahindra/xuv500/specifications/
# 688
# Unused Links count is 132
# https://autoportal.com/newcars/mahindra/verito-ev/specifications/
# 691
# Unused Links count is 131
# https://autoportal.com/newcars/tata/hexa/specifications/
# 698
# Unused Links count is 130
# https://autoportal.com/newcars/toyota/innova-facelift/specifications/
# 714
# Unused Links count is 129
# https://autoportal.com/newcars/jeep/compass/specifications/
# 735
# Unused Links count is 128
# https://autoportal.com/newcars/toyota/corolla-altis/specifications/
# 741
# Unused Links count is 127
# https://autoportal.com/newcars/honda/civic/specifications/
# 746
# Unused Links count is 126
# https://autoportal.com/newcars/mg/ezs/specifications/
# Unused Links count is 126
# Attempts for Honda Civicis2
# https://autoportal.com/newcars/mg/ezs/specifications/
# 748
# Unused Links count is 125
# https://autoportal.com/newcars/kia/grand-carnival/specifications/
# 753
# Unused Links count is 124
# https://autoportal.com/newcars/skoda/superb/specifications/
# 760
# Unused Links count is 123
# https://autoportal.com/newcars/volvo/v40-hatchback/specifications/
# 762
# Unused Links count is 122
# https://autoportal.com/newcars/toyota/fortuner/specifications/
# 769
# Unused Links count is 121
# https://autoportal.com/newcars/ford/endeavour/specifications/
# 772
# Unused Links count is 120
# https://autoportal.com/newcars/mini/3-door/specifications/
# 774
# Unused Links count is 119
# https://autoportal.com/newcars/skoda/kodiaq-scout/specifications/
# 775
# Unused Links count is 118
# https://autoportal.com/newcars/bmw/x1/specifications/
# 780
# Unused Links count is 117
# https://autoportal.com/newcars/volvo/s60/specifications/
# 782
# Unused Links count is 116
# https://autoportal.com/newcars/bmw/3-series/specifications/
# 785
# Unused Links count is 115
# https://autoportal.com/newcars/volvo/volvo-s60-cross-country/specifications/
# 786
# Unused Links count is 114
# https://autoportal.com/newcars/audi/q5/specifications/
# 790
# Unused Links count is 113
# https://autoportal.com/newcars/landrover/range-rover-evoque/specifications/
# 794
# Unused Links count is 112
# https://autoportal.com/newcars/mercedesbenz/e-class/specifications/
# 802
# Unused Links count is 111
# https://autoportal.com/newcars/volvo/xc60/specifications/
# 803
# Unused Links count is 110
# https://autoportal.com/newcars/bmw/x4/specifications/
# 806
# Unused Links count is 109
# https://autoportal.com/newcars/jeep/wrangler/specifications/
# 807
# Unused Links count is 108
# https://autoportal.com/newcars/mercedesbenz/c-class-cabriolet/specifications/
# 808
# Unused Links count is 107
# https://autoportal.com/newcars/bmw/z4/specifications/
# 810
# Unused Links count is 106
# https://autoportal.com/newcars/mercedesbenz/v-class/specifications/
# 813
# Unused Links count is 105
# https://autoportal.com/newcars/audi/q7/specifications/
# 819
# Unused Links count is 104
# https://autoportal.com/newcars/landrover/range-rover-evoque-convertible/specifications/
# 820
# Unused Links count is 103
# https://autoportal.com/newcars/landrover/velar/specifications/
# 822
# Unused Links count is 102
# https://autoportal.com/newcars/mercedesbenz/e-class-all-terrain/specifications/
# 823
# Unused Links count is 101
# https://autoportal.com/newcars/volvo/xc90/specifications/
# 828
# Unused Links count is 100
# https://autoportal.com/newcars/landrover/range-rover-sport/specifications/
# 838
# Unused Links count is 99
# https://autoportal.com/newcars/jaguar/xj/specifications/
# 841
# Unused Links count is 98
# https://autoportal.com/newcars/porsche/cayenne/specifications/
# 844
# Unused Links count is 97
# https://autoportal.com/newcars/maserati/ghibli/specifications/
# 847
# Unused Links count is 96
# https://autoportal.com/newcars/toyota/land-cruiser/specifications/
# 848
# Unused Links count is 95
# https://autoportal.com/newcars/audi/rs7/specifications/
# 849
# Unused Links count is 94
# https://autoportal.com/newcars/landrover/range-rover/specifications/
# 859
# Unused Links count is 93
# https://autoportal.com/newcars/maserati/grancabrio/specifications/
# 860
# Unused Links count is 92
# https://autoportal.com/newcars/mercedesbenz/amg-gt/specifications/
# 863
# Unused Links count is 91
# https://autoportal.com/newcars/mercedesbenz/amg-gt-4-door-coupe/specifications/
# 864
# Unused Links count is 90
# https://autoportal.com/newcars/lamborghini/huracan/specifications/
# 873
# Unused Links count is 89
# https://autoportal.com/newcars/ferrari/488-gtb/specifications/
# 875
# Unused Links count is 88
# https://autoportal.com/newcars/ferrari/gtc4-lusso/specifications/
# 877
# Unused Links count is 87
# https://autoportal.com/newcars/lamborghini/aventador/specifications/
# 880
# Unused Links count is 86
# https://autoportal.com/newcars/rollsroyce/dawn/specifications/
# 881
# Unused Links count is 85
# https://autoportal.com/newcars/rollsroyce/drophead-coupe/specifications/
# 882
# Unused Links count is 84
# https://autoportal.com/newcars/marutisuzuki/omni/specifications/
# 884
# Unused Links count is 83
# https://autoportal.com/newcars/datsun/go-plus/specifications/
# 893
# Unused Links count is 82
# https://autoportal.com/newcars/fiat/punto-evo-pure/specifications/
# 895
# Unused Links count is 81
# https://autoportal.com/newcars/ford/figo/specifications/
# 901
# Unused Links count is 80
# https://autoportal.com/newcars/marutisuzuki/baleno/specifications/
# 914
# Unused Links count is 79
# https://autoportal.com/newcars/hyundai/grand-i10/specifications/
# 920
# Unused Links count is 78
# https://autoportal.com/newcars/fiat/linea-classic/specifications/
# 923
# Unused Links count is 77
# https://autoportal.com/newcars/nissan/sunny/specifications/
# 930
# Unused Links count is 76
# https://autoportal.com/newcars/marutisuzuki/ertiga/specifications/
# 940
# Unused Links count is 75
# https://autoportal.com/newcars/marutisuzuki/baleno-rs/specifications/
# 941
# Unused Links count is 74
# https://autoportal.com/newcars/honda/wrv/specifications/
# 950
# Unused Links count is 73
# https://autoportal.com/newcars/mahindra/tuv300/specifications/
# 957
# Unused Links count is 72
# https://autoportal.com/newcars/marutisuzuki/s-cross-sx4/specifications/
# 961
# Unused Links count is 71
# https://autoportal.com/newcars/renault/kaptur/specifications/
# 965
# Unused Links count is 70
# https://autoportal.com/newcars/mahindra/xylo/specifications/
# 970
# Unused Links count is 69
# https://autoportal.com/newcars/kia/seltos/specifications/
# 986
# Unused Links count is 68
# https://autoportal.com/newcars/nissan/terrano/specifications/
# 992
# Unused Links count is 67
# https://autoportal.com/newcars/tata/safari-storme/specifications/
# 996
# Unused Links count is 66
# https://autoportal.com/newcars/mg/hector/specifications/
# 1007
# Unused Links count is 65
# https://autoportal.com/newcars/tata/nexon-ev/specifications/
# 1010
# Unused Links count is 64
# https://autoportal.com/newcars/hyundai/elantra/specifications/
# 1014
# Unused Links count is 63
# https://autoportal.com/newcars/hyundai/tucson/specifications/
# 1022
# Unused Links count is 62
# https://autoportal.com/newcars/volkswagen/passat/specifications/
# 1026
# Unused Links count is 61
# https://autoportal.com/newcars/mercedesbenz/a-class/specifications/
# 1028
# Unused Links count is 60
# https://autoportal.com/newcars/volvo/v40-cross-country/specifications/
# 1030
# Unused Links count is 59
# https://autoportal.com/newcars/mini/countryman/specifications/
# 1034
# Unused Links count is 58
# https://autoportal.com/newcars/mercedesbenz/c-class/specifications/
# 1040
# Unused Links count is 57
# https://autoportal.com/newcars/toyota/prius/specifications/
# 1041
# Unused Links count is 56
# https://autoportal.com/newcars/lexus/es/specifications/
# 1042
# Unused Links count is 55
# https://autoportal.com/newcars/lexus/nx-300h/specifications/
# 1044
# Unused Links count is 54
# https://autoportal.com/newcars/jaguar/f-pace/specifications/
# 1046
# Unused Links count is 53
# https://autoportal.com/newcars/volvo/v90/specifications/
# 1047
# Unused Links count is 52
# https://autoportal.com/newcars/audi/a5-cabriolet/specifications/
# 1048
# Unused Links count is 51
# https://autoportal.com/newcars/mercedesbenz/gle/specifications/
# 1050
# Unused Links count is 50
# https://autoportal.com/newcars/mercedesbenz/cls/specifications/
# 1051
# Unused Links count is 49
# https://autoportal.com/newcars/bmw/x7/specifications/
# 1053
# Unused Links count is 48
# https://autoportal.com/newcars/bmw/m4/specifications/
# 1054
# Unused Links count is 47
# https://autoportal.com/newcars/porsche/911/specifications/
# 1056
# Unused Links count is 46
# https://autoportal.com/newcars/nissan/gtr/specifications/
# 1057
# Unused Links count is 45
# https://autoportal.com/newcars/astonmartin/vantage/specifications/
# 1058
# Unused Links count is 44
# https://autoportal.com/newcars/astonmartin/rapide/specifications/
# 1059
# Unused Links count is 43
# https://autoportal.com/newcars/ferrari/812/specifications/
# 1060
# Unused Links count is 42
# https://autoportal.com/newcars/marutisuzuki/alto-800-tour/specifications/
# 1062
# Unused Links count is 41
# https://autoportal.com/newcars/hyundai/grand-i10-nios/specifications/
# 1072
# Unused Links count is 40
# https://autoportal.com/newcars/hyundai/xcent/specifications/
# 1081
# Unused Links count is 39
# https://autoportal.com/newcars/nissan/micra/specifications/
# 1085
# Unused Links count is 38
# https://autoportal.com/newcars/mahindra/bolero/specifications/
# 1090
# Unused Links count is 37
# https://autoportal.com/newcars/marutisuzuki/ciaz/specifications/
# 1104
# Unused Links count is 36
# https://autoportal.com/newcars/skoda/rapid/specifications/
# 1118
# Unused Links count is 35
# https://autoportal.com/newcars/fiat/abarth-punto/specifications/
# 1119
# Unused Links count is 34
# https://autoportal.com/newcars/hyundai/creta/specifications/
# 1137
# Unused Links count is 33
# https://autoportal.com/newcars/tata/harrier/specifications/
# 1143
# Unused Links count is 32
# https://autoportal.com/newcars/isuzu/dmax-v-cross/specifications/
# 1146
# Unused Links count is 31
# https://autoportal.com/newcars/mitsubishi/outlander/specifications/
# 1147
# Unused Links count is 30
# https://autoportal.com/newcars/mercedesbenz/gla-class/specifications/
# 1153
# Unused Links count is 29
# https://autoportal.com/newcars/honda/accord/specifications/
# 1154
# Unused Links count is 28
# https://autoportal.com/newcars/bmw/5-series/specifications/
# 1157
# Unused Links count is 27
# https://autoportal.com/newcars/bmw/6-series/specifications/
# 1161
# Unused Links count is 26
# https://autoportal.com/newcars/porsche/macan/specifications/
# 1163
# Unused Links count is 25
# https://autoportal.com/newcars/jaguar/f-type/specifications/
# 1171
# Unused Links count is 24
# https://autoportal.com/newcars/bmw/m5/specifications/
# 1172
# Unused Links count is 23
# https://autoportal.com/newcars/lexus/lx-570/specifications/
# 1173
# Unused Links count is 22
# https://autoportal.com/newcars/ferrari/458-spider/specifications/
# 1174
# Unused Links count is 21
# https://autoportal.com/newcars/marutisuzuki/wagon-r/specifications/
# 1188
# Unused Links count is 20
# https://autoportal.com/newcars/tata/tiago-nrg/specifications/
# 1191
# Unused Links count is 19
# https://autoportal.com/newcars/mahindra/nuvosport/specifications/
# 1197
# Unused Links count is 18
# https://autoportal.com/newcars/nissan/kicks/specifications/
# 1205
# Unused Links count is 17
# https://autoportal.com/newcars/tata/winger/specifications/
# 1206
# Unused Links count is 16
# https://autoportal.com/newcars/hyundai/kona-electric/specifications/
# 1207
# Unused Links count is 15
# https://autoportal.com/newcars/toyota/camry/specifications/
# 1208
# Unused Links count is 14
# https://autoportal.com/newcars/audi/a5/specifications/
# 1209
# Unused Links count is 13
# https://autoportal.com/newcars/landrover/discovery/specifications/
# 1217
# Unused Links count is 12
# https://autoportal.com/newcars/lexus/ls-500h/specifications/
# 1220
# Unused Links count is 11
# https://autoportal.com/newcars/rollsroyce/phantom/specifications/
# 1222
# Unused Links count is 10
# https://autoportal.com/newcars/fiat/punto-evo/specifications/
# 1226
# Unused Links count is 9
# https://autoportal.com/newcars/toyota/yaris/specifications/
# 1240
# Unused Links count is 8
# https://autoportal.com/newcars/skoda/octavia/specifications/
# 1252
# Unused Links count is 7
# https://autoportal.com/newcars/mercedesbenz/glc/specifications/
# 1254
# Unused Links count is 6
# https://autoportal.com/newcars/porsche/cayenne-coupe/specifications/
# 1256
# Unused Links count is 5
# https://autoportal.com/newcars/mahindra/verito/specifications/
# 1259
# Unused Links count is 4
# https://autoportal.com/newcars/mitsubishi/pajero-sport/specifications/
# 1264
# Unused Links count is 3
# https://autoportal.com/newcars/bentley/continental-flying-spur/specifications/
# 1266
# Unused Links count is 2
# https://autoportal.com/newcars/honda/city/specifications/
# 1276
# Unused Links count is 1
# https://autoportal.com/newcars/mitsubishi/montero/specifications/
# 1277
# Unused Links count is 0

# %%
carInfoFull
# Out:
#      12v_Power_Outlet ARAI_Certified_Mileage                   Audiosystem  \
# 0                 Yes          23.6 km/litre   CD Player with USB & Aux-in
# 1                 Yes          23.6 km/litre                  Not on offer
# 2                 Yes                    NaN                  Not on offer
# 3                 Yes          21.9 km/litre   CD Player with USB & Aux-in
# 4                 Yes          23.6 km/litre                  Not on offer
# ...               ...                    ...                           ...
# 1271                3          25.1 km/litre  DVD Player with USB & Aux-in
# 1272                3          25.1 km/litre  DVD Player with USB & Aux-in
# 1273                3          22.6 km/litre  DVD Player with USB & Aux-in
# 1274                3          17.8 km/litre   CD Player with USB & Aux-in
# 1275              Yes         11.56 km/litre   CD Player with USB & Aux-in
#
#      Aux-in_Compatibility Average_Fuel_Consumption  \
# 0                     Yes                      Yes
# 1                     NaN                      Yes
# 2                     NaN                      Yes
# 3                     Yes                      Yes
# 4                     NaN                      Yes
# ...                   ...                      ...
# 1271                  Yes                      Yes
# 1272                  Yes                      Yes
# 1273                  Yes                      Yes
# 1274                  Yes                      Yes
# 1275                  Yes                      Yes
#
#                                          Basic_Warranty Bluetooth  Body_Type  \
# 0     2 years /75000 Kms (years/distance whichever c...       Yes  Hatchback
# 1     2 years /75000 Kms (years/distance whichever c...       NaN  Hatchback
# 2     2 years /75000 Kms (years/distance whichever c...       NaN  Hatchback
# 3     2 years /75000 Kms (years/distance whichever c...       Yes  Hatchback
# 4     2 years /75000 Kms (years/distance whichever c...       NaN  Hatchback
# ...                                                 ...       ...        ...
# 1271     2 Years / 40,000 Kms (Whichever comes earlier)       Yes      Sedan
# 1272     2 Years / 40,000 Kms (Whichever comes earlier)       Yes      Sedan
# 1273     2 Years / 40,000 Kms (Whichever comes earlier)       Yes      Sedan
# 1274     2 Years / 40,000 Kms (Whichever comes earlier)       Yes      Sedan
# 1275                                                NaN       Yes        SUV
#
#             Boot-lid_Opener   Boot_Space  ... Ambient_Lightning  \
# 0                  Internal   110 litres  ...               NaN
# 1                  Internal   110 litres  ...               NaN
# 2                  Internal   110 litres  ...               NaN
# 3                  Internal    94 litres  ...               NaN
# 4                  Internal   110 litres  ...               NaN
# ...                     ...          ...  ...               ...
# 1271  Internal, With Remote   510 litres  ...               NaN
# 1272  With Remote, Internal   510 litres  ...               NaN
# 1273  Internal, With Remote   510 litres  ...               NaN
# 1274               Internal   510 litres  ...               NaN
# 1275               Internal  1050 litres  ...               NaN
#
#      Heads-Up_Display Power_Seats Welcome_Lights Heated_Seats USB_Ports  \
# 0                 NaN         NaN            NaN          NaN       NaN
# 1                 NaN         NaN            NaN          NaN       NaN
# 2                 NaN         NaN            NaN          NaN       NaN
# 3                 NaN         NaN            NaN          NaN       NaN
# 4                 NaN         NaN            NaN          NaN       NaN
# ...               ...         ...            ...          ...       ...
# 1271              NaN         NaN            NaN          NaN       NaN
# 1272              NaN         NaN            NaN          NaN       NaN
# 1273              NaN         NaN            NaN          NaN       NaN
# 1274              NaN         NaN            NaN          NaN       NaN
# 1275              NaN         Yes            NaN   Only front       NaN
#
#      Engine_Type Electric_Range Battery Electric_Motor
# 0            NaN            NaN     NaN            NaN
# 1            NaN            NaN     NaN            NaN
# 2            NaN            NaN     NaN            NaN
# 3            NaN            NaN     NaN            NaN
# 4            NaN            NaN     NaN            NaN
# ...          ...            ...     ...            ...
# 1271         NaN            NaN     NaN            NaN
# 1272         NaN            NaN     NaN            NaN
# 1273         NaN            NaN     NaN            NaN
# 1274         NaN            NaN     NaN            NaN
# 1275         NaN            NaN     NaN            NaN
#
# [1276 rows x 141 columns]

# %%
#carInfoFull.to_csv(r'/Users/Abhinav/Movies/DataSets/cars_ds.csv',header=True ,cols=['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration', 'Emission_Norm', 'Engine_Location', 'Fuel_System', 'Fuel_Tank_Capacity', 'Fuel_Type', 'Height', 'Length', 'Width', 'Body_Type', 'Doors', 'City_Mileage', 'Highway_Mileage', 'ARAI_Certified_Mileage', 'ARAI_Certified_Mileage_for_CNG', 'Kerb_Weight', 'Gears', 'Ground_Clearance', 'Front_Brakes', 'Rear_Brakes', 'Front_Suspension', 'Rear_Suspension', 'Front_Track', 'Rear_Track', 'Front_Tyre_&_Rim', 'Rear_Tyre_&_Rim', 'Power_Steering', 'Power_Windows', 'Power_Seats', 'Keyless_Entry', 'Power', 'Torque', 'Odometer', 'Speedometer', 'Tachometer', 'Tripmeter', 'Seating_Capacity', 'Seats_Material', 'Type', 'Wheelbase', 'Wheels_Size', 'Start_/_Stop_Button','12v_Power_Outlet','Audiosystem','Aux-in_Compatibility','Average_Fuel_Consumption','Basic_Warranty' ,'Bluetooth','Boot-lid_Opener' ,'Boot_Space' ,'CD_/_MP3_/_DVD_Player' ,'Central_Locking' ,'Child_Safety_Locks' ,'Clock' ,'Cup_Holders' ,'Distance_to_Empty' ,'Door_Pockets' ,'Engine_Malfunction_Light' ,'Extended_Warranty' ,'FM_Radio' ,'Fuel-lid_Opener' ,'Fuel_Gauge' ,'Handbrake' ,'Instrument_Console' ,'Low_Fuel_Warning' ,'Minimum_Turning_Radius' ,'Multifunction_Display' ,'Sun_Visor' ,'Third_Row_AC_Vents' ,'Ventilation_System' ,'Auto-Dimming_Rear-View_Mirror' ,'Hill_Assist' ,'Gear_Indicator' ,'3_Point_Seat-Belt_in_Middle_Rear_Seat' ,'Ambient_Lightning' ,'Cargo/Boot_Lights' ,'Drive_Modes' ,'Engine_Immobilizer' ,'High_Speed_Alert_System' ,'Lane_Watch_Camera/_Side_Mirror_Camera' ,'Passenger_Side_Seat-Belt_Reminder' ,'Seat_Back_Pockets' ,'Voice_Recognition' ,'Walk_Away_Auto_Car_Lock' ,'ABS_(Anti-lock_Braking_System)' ,'Headlight_Reminder' ,'Adjustable_Headrests' ,'Gross_Vehicle_Weight' ,'Airbags' ,'Door_Ajar_Warning' ,'EBD_(Electronic_Brake-force_Distribution)' ,'Fasten_Seat_Belt_Warning' ,'Gear_Shift_Reminder' ,'Number_of_Airbags' ,'Compression_Ratio' ,'Adjustable_Steering_Column' ,'Other_Specs' ,'Other_specs' ,'Parking_Assistance' ,'Key_Off_Reminder' ,'USB_Compatibility' ,'Android_Auto' ,'Apple_CarPlay' ,'Cigarette_Lighter' ,'Infotainment_Screen' ,'Multifunction_Steering_Wheel' ,'Average_Speed' ,'EBA_(Electronic_Brake_Assist)' ,'Seat_Height_Adjustment' ,'Navigation_System' ,'Second_Row_AC_Vents' ,'Tyre_Pressure_Monitoring_System' ,'Rear_Center_Armrest' ,'iPod_Compatibility' ,'ESP_(Electronic_Stability_Program)' ,'Cooled_Glove_Box' ,'Recommended_Tyre_Pressure' ,'Heated_Seats' ,'Turbocharger' ,'ISOFIX_(Child-Seat_Mount)' ,'Rain_Sensing_Wipers', 'Paddle_Shifters' ,'Leather_Wrapped_Steering' ,'Automatic_Headlamps' ,'Engine_Type', 'ASR_/_Traction_Control' ,'Cruise_Control' ,'USB_Ports' ,'Heads-Up_Display' ,'Welcome_Lights' ,'Battery' ,'Electric_Range'])
carInfoFull.reindex(columns=col_list).to_csv(r'/Users/Abhinav/Movies/DataSets/cars_ds_final.csv',header=True)

# %%
'''
make_final = ''
model_final = ''
for word in string.lower().split():
    if word.lower() in make.lower(): 
        make_final = make_final + "" + word.title() + " "
for word in string.lower().split():
    if word.lower() not in make_final.lower(): 
        model_final = model_final + "" + word.title() + " "
'''

# %%
'''
make = 'datsun'
print(make.title())
#'marutisuzuki'
'''

# %%
'''
make_model_variant = 'Ex-Showroom Price, Offers & Key Features of Datsun redi-GO D (Petrol)'
make_model = 'Specifications of Datsun redi-GO'
make_model_string = make_model.split("of ",1)[1]
make_model_variant_string = make_model_variant.rsplit(' ', 1)[0].split("of ",1)[1]
print(make_model_string)
print(make_model_variant_string)
'''

# %%
'''
make_final = ''
model_final = ''
variant_final = ''

for make_name in make_model_string.lower().split():
    if make_name.lower() in make.lower(): 
        make_final = make_final + "" + make_name.title() + " "

for model_name in make_model_string.lower().split():
    if model_name.lower() not in make.lower(): 
        model_final = model_final + "" + model_name.title() + " "
vf = set(make_model_variant_string.lower().split()) - set(make_model_string.lower().split())
for i in vf:
    variant_final = variant_final + "" + i.title() + " "
    '''

# %%
#make_final

# %%
#model_final

# %%
#variant_final
